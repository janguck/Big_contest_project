# %%
import matplotlib as plt
import pandas as pd
import numpy as np
from math import sqrt
from statistics import mean
from numpy import array
import numpy as np

# %%
merge_table = pd.read_csv('merge_table_test')

# %%
merge_table["SIU_CUST_YN"] = None

# %%
merge_table['AGE'].fillna((merge_table['AGE'].mean()), inplace=True)

merge_table['AGE'] = merge_table['AGE'].map(lambda x:0 if x < 11 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:10 if x >10 and x<21 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:20 if x >20 and x<31 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:30 if x >30 and x<41 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:40 if x >40 and x<51 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:50 if x >50 and x<61 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:60 if x >60 and x<71 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:70 if x >70 and x<81 else x)
merge_table['AGE'] = merge_table['AGE'].map(lambda x:80 if x >80  else x)


merge_table['AGE'] = merge_table['AGE'].map(lambda x:100 if x == 50 else x) 
merge_table['AGE'] = merge_table['AGE'].map(lambda x:70 if x == 30 or x == 40 or x == 60else x) 
merge_table['AGE'] = merge_table['AGE'].map(lambda x:40 if x == 20 else x) 
merge_table['AGE'] = merge_table['AGE'].map(lambda x:0 if  x != 100 and x!=70 and x!=40  else x)

# %%
merge_table['MAXCRDT']= merge_table['MAXCRDT'].map(lambda x:80 if x<=6 else x)
merge_table['MAXCRDT']= merge_table['MAXCRDT'].map(lambda x:50 if x<50 and x>7 else x)
merge_table['MAXCRDT'] = merge_table['MAXCRDT'].map(lambda x:0 if x!= 80 and x!=50  else x)

# %%
merge_table['CTPR'] = merge_table['CTPR'].map(lambda x:50 if x == '강원' or x == '광주' or x == '부산' or x == '인천' or x == '전북' else x) 
merge_table['CTPR'] = merge_table['CTPR'].map(lambda x:30 if x == '경기' or x=='경남' or x=='경북'  or x=='대구'or x=='대전' or x=='서울' or x=='전남' else x)
merge_table['CTPR'] = merge_table['CTPR'].map(lambda x:0 if  x != 30 and x!=50  else x)

# %%
merge_table["ACCI_OCCP_GRP1"] = merge_table["ACCI_OCCP_GRP1"].map(lambda x : 4 if x == '2.자영업' else x)   
merge_table["ACCI_OCCP_GRP1"] = merge_table["ACCI_OCCP_GRP1"].map(lambda x : 3 if x == '1.주부' or x == '5.서비스' else x)    
merge_table["ACCI_OCCP_GRP1"] = merge_table["ACCI_OCCP_GRP1"].map(lambda x : 2 if x == '3.사무직' or x == '8.기타' else x)   
merge_table["ACCI_OCCP_GRP1"] = merge_table["ACCI_OCCP_GRP1"].map(lambda x : 1 if x == '4.전문직' or x == '6.제조업' or x == '7.1차산업' else x)    
merge_table["ACCI_OCCP_GRP1"].fillna((merge_table["ACCI_OCCP_GRP1"].mean()), inplace=True)

# %%
merge_table["CRNT_PROG_DVSN"] = merge_table["CRNT_PROG_DVSN"].map(lambda x : 10 if x == 33 else x)   
merge_table["CRNT_PROG_DVSN"] = merge_table["CRNT_PROG_DVSN"].map(lambda x : 6 if x == 23 else x)   
merge_table["CRNT_PROG_DVSN"] = merge_table["CRNT_PROG_DVSN"].map(lambda x : 3 if x == 11 else x)   
merge_table["CRNT_PROG_DVSN"] = merge_table["CRNT_PROG_DVSN"].map(lambda x : 1 if x != 10 and x != 6 and x != 3 else x)   
merge_table["CRNT_PROG_DVSN"].fillna((merge_table["CRNT_PROG_DVSN"].mean()), inplace=True)

# %%
merge_table["DMND_RESN_CODE"] = merge_table["DMND_RESN_CODE"].map(lambda x : 100 if x == 2 or x == 4 else x)   
merge_table["DMND_RESN_CODE"] = merge_table["DMND_RESN_CODE"].map(lambda x : 40 if x == 5 else x)   
merge_table["DMND_RESN_CODE"] = merge_table["DMND_RESN_CODE"].map(lambda x : 10 if x == 1 or x == 3 or x == 6 else x)   
merge_table["DMND_RESN_CODE"] = merge_table["DMND_RESN_CODE"].map(lambda x : 5 if x == 7 else x)   
merge_table["DMND_RESN_CODE"] = merge_table["DMND_RESN_CODE"].map(lambda x : 1 if x == 9 else x)   
merge_table["DMND_RESN_CODE"].fillna((merge_table["DMND_RESN_CODE"].mean()), inplace=True)

# %%
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 70 if  x == 1 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 30 if  x == 2 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 130 if  x == 3 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 90 if  x == 4 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 10 if  x == 5 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 50 if  x == 6 else x)
merge_table['SALE_CHNL_CODE']=merge_table['SALE_CHNL_CODE'].map(lambda x: 110 if  x == 7 else x)

# %%
merge_table['CNTT_STAT_CODE']=merge_table['CNTT_STAT_CODE'].map(lambda x: 0 if x == 1 or x == 2 or x == 9 or x == 'A' or x == 'C' or x == 'H' or x == 'I' or x == 'L' else x)
merge_table['CNTT_STAT_CODE']=merge_table['CNTT_STAT_CODE'].map(lambda x: 2 if x == 3 or x == 'B' or x == 'E' or x == 'J' else 4)

# %%
merge_table.sort(columns="CUST_ID", axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
# Out:
# /home/jangsion/miniconda3/envs/ml_python/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        CUST_ID SIU_CUST_YN  AGE  CTPR  MAXCRDT  ACCI_OCCP_GRP1  \
# 7665        37        None   70    30      0.0         3.00000
# 13524       37        None   70    30      0.0         3.00000
# 9147        37        None   70    30      0.0         3.00000
# 7666        37        None   70    30      0.0         3.00000
# 7669        37        None   70    30      0.0         3.00000
# 9146        37        None   70    30      0.0         3.00000
# 24157       37        None   70    30      0.0         3.00000
# 7668        37        None   70    30      0.0         3.00000
# 7667        37        None   70    30      0.0         3.00000
# 14153       51        None   70    30      0.0         4.00000
# 16991       51        None   70    30      0.0         3.00000
# 21399       51        None   70    30      0.0         4.00000
# 13232       51        None   70    30      0.0         3.00000
# 16085       51        None   70    30      0.0         4.00000
# 3583        51        None   70    30      0.0         3.00000
# 24715       51        None   70    30      0.0         4.00000
# 17110       51        None   70    30      0.0         4.00000
# 6103        51        None   70    30      0.0         3.00000
# 7206        51        None   70    30      0.0         2.43492
# 1685        51        None   70    30      0.0         3.00000
# 7117        51        None   70    30      0.0         4.00000
# 7114        51        None   70    30      0.0         3.00000
# 14476       51        None   70    30      0.0         4.00000
# 16728       51        None   70    30      0.0         4.00000
# 19707       51        None   70    30      0.0         4.00000
# 17184       51        None   70    30      0.0         3.00000
# 17138       51        None   70    30      0.0         3.00000
# 11923       51        None   70    30      0.0         4.00000
# 2987        51        None   70    30      0.0         4.00000
# 22432       51        None   70    30      0.0         4.00000
# ...        ...         ...  ...   ...      ...             ...
# 21117    22294        None   70     0     80.0         1.00000
# 13138    22294        None   70     0     80.0         1.00000
# 15617    22294        None   70     0     80.0         1.00000
# 24103    22294        None   70     0     80.0         1.00000
# 26437    22294        None   70     0     80.0         1.00000
# 1214     22294        None   70     0     80.0         1.00000
# 22798    22295        None  100    30     80.0         3.00000
# 16714    22295        None  100    30     80.0         3.00000
# 17208    22295        None  100    30     80.0         3.00000
# 26097    22295        None  100    30     80.0         3.00000
# 12393    22304        None   70    30     50.0         2.00000
# 7953     22305        None   70    30     80.0         3.00000
# 2205     22305        None   70    30     80.0         3.00000
# 14054    22305        None   70    30     80.0         3.00000
# 4819     22320        None   70    30     50.0         2.00000
# 11317    22328        None   70    30     80.0         1.00000
# 6912     22328        None   70    30     80.0         1.00000
# 11173    22329        None    0    30     80.0         2.00000
# 14439    22329        None    0    30     80.0         2.00000
# 2197     22342        None   40    50     80.0         1.00000
# 59       22342        None   40    50     80.0         1.00000
# 17483    22342        None   40    50     80.0         1.00000
# 14580    22342        None   40    50     80.0         1.00000
# 24439    22342        None   40    50     80.0         1.00000
# 13233    22342        None   40    50     80.0         1.00000
# 7753     22383        None   70    30     80.0         2.00000
# 5889     22383        None   70    30     80.0         2.00000
# 11609    22383        None   70    30     80.0         2.00000
# 19574    22383        None   70    30     80.0         2.00000
# 18732    22383        None   70    30     80.0         2.00000
#
#        CRNT_PROG_DVSN  DMND_RESN_CODE  VLID_HOSP_OTDA  NON_PAY_RATIO  \
# 7665                3              40               0       0.000000
# 13524               3              40               0       0.000000
# 9147                3              40               0       0.000000
# 7666                3              40               0       0.000000
# 7669                3              40               0       0.000000
# 9146                3              40               0       0.000000
# 24157               3              40               0       0.000000
# 7668                3              40               0       0.000000
# 7667                3              40               0       0.000000
# 14153               6              10               8       0.000000
# 16991               6             100               8       0.000000
# 21399               3             100               6       0.000000
# 13232               6              40               0       0.000000
# 16085               6             100               6       0.000000
# 3583                6              40               0       0.000000
# 24715               6              10               0       0.000000
# 17110               6             100               8       0.000000
# 6103                6              40               0       0.000000
# 7206                6             100               8       0.880125
# 1685                6             100               8       0.000000
# 7117                6             100               6       0.000000
# 7114                6             100               8       0.000000
# 14476               3             100               6       0.000000
# 16728               6              10               8       0.000000
# 19707               3             100               6       0.000000
# 17184               6              10               0       0.000000
# 17138               6             100               8       0.000000
# 11923               6             100               6       0.000000
# 2987                6             100               8       0.000000
# 22432               6              10               0       0.000000
# ...               ...             ...             ...            ...
# 21117               6              10               3       0.000000
# 13138               6              10               5       0.000000
# 15617               6              10               0       0.000000
# 24103               6              10               1       0.463870
# 26437               6              10               5       0.028090
# 1214                6              10               5       0.555556
# 22798               6              10               2       0.015699
# 16714               6              10               2       0.015699
# 17208               6              10               2       0.015699
# 26097               6              10               2       0.015699
# 12393               6             100              21       0.062777
# 7953                6              10               0       0.000000
# 2205                6              10              25       0.000000
# 14054               6              10              25       0.733057
# 4819                6              10               1       0.389291
# 11317               6              10              13       0.000000
# 6912                3              10              12       0.000000
# 11173               6              10               1       0.000000
# 14439               6              10               1       0.825186
# 2197                6              10               1       0.883392
# 59                  6              10               1       0.883392
# 17483               6              10               3       0.663418
# 14580               6              10               3       0.663418
# 24439               6              10               3       0.663418
# 13233               6              10               1       0.883392
# 7753               10              10               1       0.000000
# 5889               10              10               1       0.726697
# 11609              10              10               0       0.000000
# 19574               6              10               0       0.000000
# 18732               6              10               1       0.000000
#
#        SALE_CHNL_CODE  CNTT_STAT_CODE
# 7665               70               2
# 13524              70               2
# 9147               70               4
# 7666               70               2
# 7669               70               2
# 9146               70               4
# 24157              70               4
# 7668               70               2
# 7667               70               2
# 14153              70               4
# 16991              30               4
# 21399              70               4
# 13232              30               4
# 16085              30               4
# 3583               70               4
# 24715              30               4
# 17110              70               4
# 6103               70               2
# 7206               70               2
# 1685               30               4
# 7117               70               4
# 7114               70               4
# 14476              30               4
# 16728              30               4
# 19707              70               2
# 17184              30               2
# 17138              70               4
# 11923              30               2
# 2987               70               4
# 22432              30               2
# ...               ...             ...
# 21117              70               4
# 13138              70               4
# 15617              70               4
# 24103              70               4
# 26437              70               4
# 1214               70               4
# 22798              70               4
# 16714              70               4
# 17208              70               2
# 26097              70               2
# 12393              70               2
# 7953               70               4
# 2205               70               4
# 14054              70               4
# 4819               70               4
# 11317              50               4
# 6912               50               4
# 11173              70               4
# 14439              70               4
# 2197               30               4
# 59                 30               4
# 17483              70               4
# 14580              30               4
# 24439              30               4
# 13233              70               4
# 7753               70               4
# 5889               70               4
# 11609              70               4
# 19574              70               4
# 18732              70               4
#
# [26627 rows x 12 columns]

# %%
version_3 = set([ tuple(line) for line in merge_table.values.tolist()])

# %%
real_data = []
with open("merge_table_test", "r") as sion:  
    datas = sion.readlines()
    for data in datas:
        data = data.split(",")
        real_data.append(data)

# %%
columns = []
for i in merge_table.columns:
    columns.append(i)

# %%
result = [] 
result.append(columns)

# %%
for i in version_3:
    result.append(list(i))

# %%
for i in range(len(result)):
    for j in range(len(result[i])):
        result[i][j] = str(result[i][j])

# %%
result_2 = []
for i in result:
    i[-1] = i[-1]+"\n"
    result_2.append(i)

# %%
with open("merge_table_test_real", "w") as sion: 
    for data in result_2:
        data = ",".join(data)
        sion.write(data)
    sion.close()
