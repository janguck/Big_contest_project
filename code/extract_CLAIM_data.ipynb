# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data_utf_8/BGCON_CNTT_DATA_utf_8.txt')

# %%
df[:1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c1ad0e0d7657> in <module>()
# ----> 1 df[:1]
#
# NameError: name 'df' is not defined

# %%
df_version_cust_data = pd.read_csv('../data_utf_8/BGCON_CUST_DATA_utf_8.txt')

# %%
df_version_cust_data[:100]
# Out:
#     CUST_ID  DIVIDED_SET SIU_CUST_YN  SEX  AGE  RESI_COST  RESI_TYPE_CODE  \
# 0         1            1           N    2   47      21111            20.0
# 1         2            1           N    1   53      40000            20.0
# 2         3            1           N    1   60          0             NaN
# 3         4            1           N    2   64      12861            40.0
# 4         5            1           N    2   54          0             NaN
# 5         6            1           N    1   62       6218            99.0
# 6         7            1           Y    2   60      11388            30.0
# 7         8            1           N    1   57      86527            20.0
# 8         9            1           N    1   54      22638            20.0
# 9        12            1           N    1   58      37222            20.0
# 10       13            1           Y    1   63       8140            50.0
# 11       15            1           N    1   59      23055            20.0
# ...

# %%
len_of_cust_data = len(df_version_cust_data["CUST_ID"])
len_of_claim_data = len(df["CUST_ID"])

# %%
df.insert(0, "SIU_CUST_YN","")

# %%
for i in range(len_of_claim_data):
    for j in range(len_of_cust_data):
        if df["CUST_ID"][i] == df_version_cust_data["CUST_ID"][j]:
            df.loc[i,("SIU_CUST_YN")] = df_version_cust_data["SIU_CUST_YN"][j]

# %%
df
# Out:
#        SIU_CUST_YN  POLY_NO  CUST_ID  CUST_ROLE  IRKD_CODE_DTAL  \
# 0                N        1     2805          1            1550
# 1                N        2     5658          1            1550
# 2                Y        3     4583          1            1257
# 3                N        4    14363          1            1550
# 4                N        5     1222          0            1268
# 5                N        6    10519          2            1259
# 6                         7    12775          2            1268
# 7                N        8     4605          1            1259
# 8                N        9     5310          1            1242
# 9                N       10    21766          2            1550
# 10               N       11    11278          1            1257
# 11                       12     4710          0            1234
# 12               N       13    12378          1            1268
# 13               N       14     3226          1            1550
# ...

# %%
df.to_csv("plus_y_data_CNT_DATA_utf_8")
