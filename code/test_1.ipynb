# %%
with open("../data_utf_8/BGCON_CUST_DATA_utf_8.txt", 'r') as f:
    doc = f.read().encode('utf-8').decode('utf-8')
    print(doc)
# Out:
# CUST_ID,DIVIDED_SET,SIU_CUST_YN,SEX,AGE,RESI_COST,RESI_TYPE_CODE,FP_CAREER,CUST_RGST,CTPR,OCCP_GRP_1,OCCP_GRP_2,TOTALPREM,MINCRDT,MAXCRDT,WEDD_YN,MATE_OCCP_GRP_1,MATE_OCCP_GRP_2,CHLD_CNT,LTBN_CHLD_AGE,MAX_PAYM_YM,MAX_PRM,CUST_INCM,RCBASE_HSHD_INCM,JPBASE_HSHD_INCM
# 1,1,N,2,47,21111,20,N,199910,충북,3.사무직,사무직,146980441,,,Y,3.사무직,2차산업 종사자,2,13,200811,319718,4879,10094,11337
# 2,1,N,1,53,40000,20,N,199910,서울,3.사무직,사무직,94600109,1,6,Y,1.주부,주부,2,17,200012,341341,6509,9143,6509
# 3,1,N,1,60,0,,N,199910,서울,5.서비스,2차산업 종사자,18501269,,,N,,,0,0,200305,131300,4180,0,4180
# 4,1,N,2,64,12861,40,Y,199910,경기,2.자영업,3차산업 종사자,317223657,2,99,N,,,0,0,201009,1493184,,4270,5914
# 5,1,N,2,54,0,,Y,199910,광주,2.자영업,3차산업 종사자,10506072,8,8,Y,3.사무직,고위 공무원,3,19,200807,166760,3894,0,8885
# 6,1,N,1,62,6218,99,N,199910,충남,3.사무직,고위 공무원,22313040,6,6,Y,1.주부,주부,1,34,201606,82850,,0,6449
# 7,1,Y,2,60,11388,30,N,199910,서울,5.서비스,3차산업 종사자,46522197,,,Y,,,1,26,200903,482077,3611,0,3611
# ...
